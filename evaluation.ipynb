# %% [markdown]
# # AI/ML Intelligence Hackathon - Track 4 Evaluation
#
# This notebook covers the evaluation of the Risk Prioritization pipeline.

# %%
from utils.dataloader import load_party_registry, load_ml_features
from models.features import compute_account_features
from models.baseline import train_baseline

# Evaluate baseline
pr = load_party_registry()
ml = load_ml_features()
features_df = compute_account_features(ml, pr)

model, metrics, X_test, y_test, y_score = train_baseline(features_df)
print("Metrics:", metrics)
