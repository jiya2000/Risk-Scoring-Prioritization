# %% [markdown]
# # AI/ML Intelligence Hackathon - Exploratory Data Analysis
#
# This notebook covers the mandatory EDA requirements:
# - Dataset overview (row count, column count, data types)
# - Missing value analysis
# - Data quality issues identified
# - Feature distributions
# - Correlations or relationships between variables
# - Summary of key insights derived from the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from utils.dataloader import load_party_registry, load_ml_features

# Set plotting style
plt.style.use('ggplot')

# Load data
pr = load_party_registry()
ml = load_ml_features()
